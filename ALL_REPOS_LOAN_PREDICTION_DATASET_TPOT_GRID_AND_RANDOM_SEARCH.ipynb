# %% [markdown]
# <a href="https://colab.research.google.com/github/saktheeswaranswan/random-math-addition-data-for-rnn-generator/blob/main/ALL_REPOS_LOAN_PREDICTION_DATASET_TPOT_GRID_AND_RANDOM_SEARCH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#THANKS TO ALL THIS GITHUB AUTHOR https://github.com/bhattbhavesh91/decision_tree_grid_search
#https://github.com/ShagunSharma98/Global-Structural-Earthquake-Damage-Prediction

#https://github.com/ShagunSharma98/Global-Structural-Earthquake-Damage-Prediction
#https://github.com/aanchal1308/disease-diagnosis-ML
#https://github.com/SadmanSakib93/ANN-Stratified-K-Fold-Cross-Validation-Keras-Tensorflow
#https://github.com/aanchal1308/disease-diagnosis-ML
#https://github.com/asaficontact/project_floodlight
#https://github.com/rochitasundar/Customer-profiling-using-ML-EasyVisa
#https://github.com/angeloruggieridj/MLPClassifier-with-GridSearchCV-Iris
#https://github.com/GabbyOlivares/Machine-Learning-Challenge
#https://github.com/anshul1004/MachineLearningClassificationModels
#https://github.com/yjeong5126/housing_prices
#https://github.com/imehrdadmahdavi/grid-search
#https://github.com/AmirHHasani/Auto-tuning-of-Classic-Machine-Learning-Models-Hyperparameters-Using-Scikit-Learn
#https://github.com/glubbdubdrib/lazygrid
#https://github.com/bhattbhavesh91/decision_tree_grid_search/blob/master/loan_prediction.csv
#https://github.com/bhattbhavesh91/decision_tree_grid_search

# %%
# !pip install tpot
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 KB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 MB 5.1 MB/s eta 0:00:00
# ...
#   Using cached deap-1.3.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (139 kB)
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for stopit: filename=stopit-1.1.2-py3-none-any.whl size=11953 sha256=f2ef05e37f9c654abc32c4935b1e67d5e05b1c186f24a53ff00f93907ba623a9
#   Stored in directory: /root/.cache/pip/wheels/a8/bb/8f/6b9328d23c2dcedbfeb8498b9f650d55d463089e3b8fc0bfb2
# Successfully built stopit
# ...
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 0.90
#     Uninstalling xgboost-0.90:
#       Successfully uninstalled xgboost-0.90
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
import tpot

# Load the data
data = pd.read_csv("/content/loan_data.csv")

# Split the data into features and target
X = data.drop("Loan_Status", axis=1)
y = data["Loan_Status"]

# Scale the data
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Define the Neural Network classifier
mlp = MLPClassifier()

# Define the parameter grid for Grid Search
param_grid = {
    "hidden_layer_sizes": [(50,50,50), (100,100,100), (100,100,100,100)],
    "alpha": [0.0001, 0.001, 0.01, 0.1],
    "learning_rate_init": [0.001, 0.01, 0.1],
}

# Conduct Grid Search
grid_search = GridSearchCV(mlp, param_grid, cv=5)
grid_search.fit(X_train, y_train)

# Print the best parameters and accuracy score
print("Best parameters: ", grid_search.best_params_)
print("Accuracy: ", grid_search.best_score_)

# Define the parameter distribution for Random Search
param_dist = {
    "hidden_layer_sizes": [(50,50,50), (100,100,100), (100,100,100,100)],
    "alpha": np.logspace(-6, -1, 6),
    "learning_rate_init": np.logspace(-6, -1, 6),
}

# Conduct Random Search
random_search = RandomizedSearchCV(mlp, param_distributions=param_dist, n_iter=50, cv=5)
random_search.fit(X_train, y_train)

# Print the best parameters and accuracy score
print("Best parameters: ", random_search.best_params_)
print("Accuracy: ", random_search.best_score_)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...
