# %% [markdown]
# <a href="https://colab.research.google.com/github/saktheeswaranswan/random-math-addition-data-for-rnn-generator/blob/main/mat_video_generatio_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
import time

texts = [
    "Start your journey with Blue Brain Robotics, where expert tutors provide comprehensive training in Data Science and AI.",
    "Get hands-on experience in MIT App Inventor, Full Stack Deployment, Deep Learning, and Machine Learning.",
    "Benefit from our proven track record and impressive portfolio.",
    "Stay ahead of the curve with our cutting-edge curriculum that is constantly updated to meet industry standards.",
    "Prepare for a successful career in this rapidly growing field."
]

def update_text(i):
    if i < len(texts):
        ax.clear()
        ax.text(0.5, 0.5, texts[i], ha='center', va='center', fontsize=12)
    else:
        plt.close()

fig, ax = plt.subplots()
ani = animation.FuncAnimation(fig, update_text, frames=len(texts) + 1, interval=10000)
plt.show()
ani.save("text_animation.mp4")
